# %%
import pandas as pd
import matplotlib.pyplot as plt
d=pd.read_csv("E:\python_DSBDA\heart.csv")
d
# Out:
#       age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0     125.0  212.0    0        1      168      0      1.0
# 1      53    1   0     140.0  203.0    1        0      155      1      3.1
# 2      70    1   0       NaN  174.0    0        1      125      1      2.6
# 3      61    1   0     148.0    NaN    0        1      161      0      0.0
# 4      62    0   0     138.0  294.0    1        1      106      0      1.9
# ...   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 1020   59    1   1       NaN  221.0    0        1      164      1      0.0
# 1021   60    1   0     125.0  258.0    0        0      141      1      2.8
# 1022   47    1   0       NaN    NaN    0        0      118      1      1.0
# 1023   50    0   0     110.0  254.0    0        0      159      0      0.0
# 1024   54    1   0     120.0  188.0    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
d["chol"].fillna(d["chol"].median(),inplace=True)

# %%
d
# Out:
#       age  sex  cp    trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0  125.000000  212.0    0        1      168      0      1.0
# 1      53    1   0  140.000000  203.0    1        0      155      1      3.1
# 2      70    1   0  131.682087  174.0    0        1      125      1      2.6
# 3      61    1   0  148.000000  240.0    0        1      161      0      0.0
# 4      62    0   0  138.000000  294.0    1        1      106      0      1.9
# ...   ...  ...  ..         ...    ...  ...      ...      ...    ...      ...
# 1020   59    1   1  131.682087  221.0    0        1      164      1      0.0
# 1021   60    1   0  125.000000  258.0    0        0      141      1      2.8
# 1022   47    1   0  131.682087  240.0    0        0      118      1      1.0
# 1023   50    0   0  110.000000  254.0    0        0      159      0      0.0
# 1024   54    1   0  120.000000  188.0    0        1      113      0      1.4
#
#       slope  ca  thal  target
# ...

# %%
x=d["trestbps"].mean()
d["trestbps"].fillna(x,inplace=True)
d
# Out:
#       age  sex  cp    trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0  125.000000  212.0    0        1      168      0      1.0
# 1      53    1   0  140.000000  203.0    1        0      155      1      3.1
# 2      70    1   0  131.682087  174.0    0        1      125      1      2.6
# 3      61    1   0  148.000000    NaN    0        1      161      0      0.0
# 4      62    0   0  138.000000  294.0    1        1      106      0      1.9
# ...   ...  ...  ..         ...    ...  ...      ...      ...    ...      ...
# 1020   59    1   1  131.682087  221.0    0        1      164      1      0.0
# 1021   60    1   0  125.000000  258.0    0        0      141      1      2.8
# 1022   47    1   0  131.682087    NaN    0        0      118      1      1.0
# 1023   50    0   0  110.000000  254.0    0        0      159      0      0.0
# 1024   54    1   0  120.000000  188.0    0        1      113      0      1.4
#
#       slope  ca  thal  target
# ...

# %%
d.dropna()
d
# Out:
#       age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125  212.0    0        1      168      0      1.0
# 1      53    1   0       140  203.0    1        0      155      1      3.1
# 2      70    1   0       145  174.0    0        1      125      1      2.6
# 3      61    1   0       148  250.0    0        1      161      0      0.0
# 4      62    0   0       138  294.0    1        1      106      0      1.9
# ...   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140  221.0    0        1      164      1      0.0
# 1021   60    1   0       125  258.0    0        0      141      1      2.8
# 1022   47    1   0       110  250.0    0        0      118      1      1.0
# 1023   50    0   0       110  254.0    0        0      159      0      0.0
# 1024   54    1   0       120  188.0    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
d.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1020     True
# 1021     True
# 1022     True
# 1023     True
# 1024     True
# Length: 1025, dtype: bool

# %%
y=d
y.drop_duplicates(inplace=True)
y
# Out:
#       age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0     125.0  212.0    0        1      168      0      1.0
# 1      53    1   0     140.0  203.0    1        0      155      1      3.1
# 2      70    1   0       NaN  174.0    0        1      125      1      2.6
# 3      61    1   0     148.0    NaN    0        1      161      0      0.0
# 4      62    0   0     138.0  294.0    1        1      106      0      1.9
# ...   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 878    54    1   0     120.0  188.0    0        1      113      0      1.4
# 1013   58    1   0     114.0    NaN    0        2      140      0      4.4
# 1018   41    1   0       NaN    NaN    0        0      158      0      0.0
# 1020   59    1   1       NaN  221.0    0        1      164      1      0.0
# 1022   47    1   0       NaN    NaN    0        0      118      1      1.0
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
for x in y.index:
    if y.loc[x,"age"]>70:
        y.drop(x,inplace=True)

# %%
y
# Out:
#       age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0     125.0  212.0    0        1      168      0      1.0
# 1      53    1   0     140.0  203.0    1        0      155      1      3.1
# 2      70    1   0       NaN  174.0    0        1      125      1      2.6
# 3      61    1   0     148.0    NaN    0        1      161      0      0.0
# 4      62    0   0     138.0  294.0    1        1      106      0      1.9
# ...   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 878    54    1   0     120.0  188.0    0        1      113      0      1.4
# 1013   58    1   0     114.0    NaN    0        2      140      0      4.4
# 1018   41    1   0       NaN    NaN    0        0      158      0      0.0
# 1020   59    1   1       NaN  221.0    0        1      164      1      0.0
# 1022   47    1   0       NaN    NaN    0        0      118      1      1.0
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
d1=d.groupby("age")["chol"].mean()
d1
# Out:
# age
# 29    204.000000
# 34    193.200000
# 35    209.200000
# 37    232.500000
# 38    193.666667
# 39    236.857143
# 40    196.090909
# 41    219.645161
# 42    248.320000
# 43    256.923077
# 44    220.000000
# 45    246.840000
# 46    234.608696
# 47    244.812500
# 48    250.130435
# 49    221.529412
# 50    227.000000
# 51    257.948718
# 52    226.348837
# 53    234.192308
# 54    253.905660
# 55    282.034483
# 56    259.131579
# 57    241.877193
# 58    251.848485
# 59    238.282609
# 60    245.333333
# 61    245.133333
# 62    256.486486
# 63    263.093750
# 64    275.848485
# 65    276.185185
# 66    242.833333
# 67    280.870968
# 68    238.750000
# 69    242.333333
# 70    251.857143
# 71    232.909091
# 74    269.000000
# 76    197.000000
# 77    304.000000
# Name: chol, dtype: float64

# %%
mean_cholestrol=d1.rename("MeanChol").reset_index()

# %%
d1=d.merge(mean_cholestrol)
d1
# Out:
#       age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0     125.0  212.0    0        1      168      0      1.0
# 1      52    1   0     128.0  204.0    1        1      156      1      1.0
# 2      52    1   1     134.0  201.0    0        1      158      0      0.8
# 3      52    1   1     134.0  201.0    0        1      158      0      0.8
# 4      52    1   3     118.0  186.0    0        0      190      0      0.0
# ...   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 1020   35    0   0     138.0  183.0    0        1      182      0      1.4
# 1021   35    1   0     120.0  198.0    0        1      130      1      1.6
# 1022   74    0   1     120.0  269.0    0        0      121      1      0.2
# 1023   74    0   1     120.0  269.0    0        0      121      1      0.2
# 1024   74    0   1     120.0  269.0    0        0      121      1      0.2
#
#       slope  ca  thal  target    MeanChol
# ...

# %%
df=pd.DataFrame(d)

# %%
X=list(df.iloc[:,0])
Y=list(df.iloc[:,4])

# %%
plt.bar(X,Y,color='g')
plt.title("Age vs Cholestrol")
plt.xlabel("Age")
plt.ylabel("Cholestrol")
# Out:
# Text(0, 0.5, 'Cholestrol')

# %%
plt.xlabel("Age")
plt.ylabel("Cholestrol")
d1.plot()
# Out:
# <AxesSubplot:xlabel='age', ylabel='Cholestrol'>

# %%
plt.scatter(X,Y)
plt.xlabel("Age") 
plt.ylabel("Cholestrol") 
plt.title("AGE Vs Cholestrol") 
plt.grid()
plt.show()
